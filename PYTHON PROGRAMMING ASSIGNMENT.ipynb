# %% [markdown]
# # Write a Python program that checks whether a given number is prime or not

# %% [markdown]
# # 1

# %%
num = int(input("Enter Your Number"))

if num == 1:
    print ("It is not a Prime Number")
if num > 1:
    for i in range (2,num):
        if num % i == 0:
            print("It is not a Prime Number")
            break
    else:
        print("It is a Prime Number")

# %% [markdown]
# # 2

# %%
import random

# Generate two random numbers
num1 = random.randint(1, 10)
num2 = random.randint(1, 10)

product = num1 * num2
user_answer = int(input(f"What is the product of {num1} and {num2}? "))
if user_answer == product:
    print("Correct! Well done.")
else:
    print(f"Incorrect. The correct answer is {product}.")

# %% [markdown]
# # 3

# %%
while True:
    try:
        choice = int(input("Enter 1 for EVEN squares, 2 for ODD Squares"))
        if choice in(1, 2):
            break
        else:
            print("Invalid choice. Please enter 1 or 2")
    except ValueError:
        print("Invalid input. Please enter a integer.")

#Calculate and print squares based on user choice
start = 100 if choice == 1 else 101
for i in range(start, 201, 2):
    print(i * i)

# %% [markdown]
# # 4

# %%
sentence = input("Write a sentence :")
counts= {}
for word in sentence.split():
    counts.setdefault(word,0)
    counts[word] += 1
print(counts)

# %% [markdown]
# # 5

# %%
value= input("Enter the value")
reversed_value = value[::-1]
if value == reversed_value:
    print("It's a Palindrome")
else:
    print("It's not a Palindrome")
